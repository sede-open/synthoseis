# %%
import main as mn

# %%
mn.build_model(user_json='/Users/Mike.McIntire/mikes_sandbox/synthoseis/config/example.json',
               run_id=3)
# Out:
# Coherent smiles will be inserted
# Salt will be NOT be inserted.
#
# Model folder: /Users/Mike.McIntire/mikes_sandbox/synthoseis/seismic_example/test4/seismic__2023.54904164_3
# Creating directory: /Users/Mike.McIntire/mikes_sandbox/synthoseis/seismic_example/test4
# Creating directory: /Users/Mike.McIntire/mikes_sandbox/synthoseis/seismic_example/test4/seismic__2023.54904164_3
# Creating directory: /Users/Mike.McIntire/mikes_sandbox/synthoseis/seismic_example/temp_folder__2023.54904164_3
#
# Keyfile created at /Users/Mike.McIntire/mikes_sandbox/synthoseis/seismic_example/test4/seismic__2023.54904164_3/seismicCube_2023.54904164.key
# Setup Complete
# self.cfg.num_lyr_lut =  25000
# onlap_layer_list =  [ 54 181 194 196]
# Number of onlapping flags: 4
#  ... horizon number for first onlap episode = 54
#  ... number of channelFlags: 0
#  ... horizon number for first channel episode: 0
# 	Indices for shallowest point in cube: 291, 13
# Building random depth map at base of model
# ...
