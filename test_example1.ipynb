# %%
import main as mn

# %%
mn.build_model(user_json='./config/example.json',
               run_id=3)
# Out:
# No coherent noise will be inserted
# Salt will be NOT be inserted.
#
# Model folder: /Users/chris.samuel/projects/synthoseis/seismic_example/test4/seismic__2023.56354860_3
# Creating directory: /Users/chris.samuel/projects/synthoseis/seismic_example/test4/seismic__2023.56354860_3
# Creating directory: /Users/chris.samuel/projects/synthoseis/seismic_example/temp_folder__2023.56354860_3
#
# Keyfile created at /Users/chris.samuel/projects/synthoseis/seismic_example/test4/seismic__2023.56354860_3/seismicCube_2023.56354860.key
# Setup Complete
# self.cfg.num_lyr_lut =  25000
# onlap_layer_list =  [ 8 13 53]
# Number of onlapping flags: 3
#  ... horizon number for first onlap episode = 8
#  ... number of channelFlags: 0
#  ... horizon number for first channel episode: 0
# 	Indices for shallowest point in cube: 137, 299
# Building random depth map at base of model
# azi, dip, dipping_plane min/mean/max = 215.0357102929054, 0.03491001221351353, 0.00, 0.18, 0.36
# ...
